# %%
import tensorflow as tf 
import matplotlib as plt
import pandas as pd 
import seaborn as sns

# %%
import tensorflow as tf 
training_set = tf.keras.utils.image_dataset_from_directory(
    'C:/Users/GEETHANJALICHARVI/OneDrive/Desktop/oral cancer copy/Oral Cancer/Oral Cancer Dataset/train',  # Path to your training directory
    labels="inferred",
    label_mode="categorical",
    batch_size=32,
    image_size=(128, 128),
    shuffle=True,
    seed=42
)
# Out:
# Found 950 files belonging to 2 classes.

# %%
import tensorflow as tf

training_set = tf.keras.utils.image_dataset_from_directory(
    'C:/Users/GEETHANJALICHARVI/OneDrive/Desktop/oral cancer copy/Oral Cancer/Oral Cancer Dataset/train',  # Path to your training directory
    labels="inferred",  # Automatically infer the labels from folder names
    label_mode="categorical",  # Labels will be one-hot encoded
    batch_size=32,
    image_size=(128, 128),  # Resize images to 128x128
    shuffle=True,  # Shuffle the dataset
    seed=42,  # Set random seed for reproducibility
    interpolation="bilinear"  # Image interpolation method
)

print("Training dataset loaded successfully.")
# Out:
# Found 950 files belonging to 2 classes.
# Training dataset loaded successfully.

# %%
validation_set = tf.keras.utils.image_dataset_from_directory(
    'C:/Users/GEETHANJALICHARVI/OneDrive/Desktop/oral cancer copy/Oral Cancer/Oral Cancer Dataset/valid',  # Use the same 'train' folder
    labels="inferred",  # Automatically infer the labels from folder names
    label_mode="categorical",  # Labels will be one-hot encoded
    batch_size=32,
    image_size=(128, 128),  # Resize images to 128x128
    shuffle=True,  # Shuffle data
    seed=42,  # Set random seed for reproducibility
    interpolation="bilinear",  # Image interpolation method
    validation_split=0.2,  # 20% of data for validation
    subset="validation"  # Set as validation data
)

print("Validation dataset loaded successfully.")
# Out:
# Found 950 files belonging to 2 classes.
# Using 190 files for validation.
# Validation dataset loaded successfully.

# %%
validation_split = 0.2  # 20% for validation
validation_set = tf.keras.utils.image_dataset_from_directory(
    'C:/Users/GEETHANJALICHARVI/OneDrive/Desktop/oral cancer copy/Oral Cancer/Oral Cancer Dataset',  # Path to the dataset directory
    labels="inferred",
    label_mode="categorical",
    batch_size=32,
    image_size=(128, 128),
    shuffle=True,
    seed=42,
    validation_split=validation_split,
    subset="validation"
)
# Out:
# Found 1900 files belonging to 3 classes.
# Using 380 files for validation.

# %%
training_set
# Out:
# <BatchDataset element_spec=(TensorSpec(shape=(None, 128, 128, 3), dtype=tf.float32, name=None), TensorSpec(shape=(None, 2), dtype=tf.float32, name=None))>

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator

datagen = ImageDataGenerator(rescale=1./255)

# Load the training dataset
training_set = datagen.flow_from_directory(
    'C:/Users/GEETHANJALICHARVI/OneDrive/Desktop/oral cancer copy/Oral Cancer/Oral Cancer Dataset/train',
    target_size=(128, 128),
    batch_size=32,
    class_mode='categorical'
)

# Load the validation dataset
validation_set = datagen.flow_from_directory(
    'C:/Users/GEETHANJALICHARVI/OneDrive/Desktop/oral cancer copy/Oral Cancer/Oral Cancer Dataset/valid',
    target_size=(128, 128),
    batch_size=32,
    class_mode='categorical'
)
# Out:
# Found 950 images belonging to 2 classes.
# Found 950 images belonging to 2 classes.

# %%
import os

def list_files_in_directory(directory):
    for root, dirs, files in os.walk(directory):
        for file in files:
            print(os.path.join(root, file))

# List files in training directory
list_files_in_directory(r'C:/Users/GEETHANJALICHARVI/OneDrive/Desktop/oral cancer copy/Oral Cancer/Oral Cancer Dataset/train')
# Out:
# C:/Users/GEETHANJALICHARVI/OneDrive/Desktop/oral cancer copy/Oral Cancer/Oral Cancer Dataset/train\class1\CANCER\001.jpeg
# C:/Users/GEETHANJALICHARVI/OneDrive/Desktop/oral cancer copy/Oral Cancer/Oral Cancer Dataset/train\class1\CANCER\002.jpeg
# C:/Users/GEETHANJALICHARVI/OneDrive/Desktop/oral cancer copy/Oral Cancer/Oral Cancer Dataset/train\class1\CANCER\003.jpeg
# C:/Users/GEETHANJALICHARVI/OneDrive/Desktop/oral cancer copy/Oral Cancer/Oral Cancer Dataset/train\class1\CANCER\004.jpeg
# C:/Users/GEETHANJALICHARVI/OneDrive/Desktop/oral cancer copy/Oral Cancer/Oral Cancer Dataset/train\class1\CANCER\005.jpeg
# C:/Users/GEETHANJALICHARVI/OneDrive/Desktop/oral cancer copy/Oral Cancer/Oral Cancer Dataset/train\class1\CANCER\006.jpeg
# C:/Users/GEETHANJALICHARVI/OneDrive/Desktop/oral cancer copy/Oral Cancer/Oral Cancer Dataset/train\class1\CANCER\007.jpeg
# C:/Users/GEETHANJALICHARVI/OneDrive/Desktop/oral cancer copy/Oral Cancer/Oral Cancer Dataset/train\class1\CANCER\008.jpeg
# ...

# %%
import os

# Path to your training directory
path = 'C:/Users/GEETHANJALICHARVI/OneDrive/Desktop/oral cancer copy/Oral Cancer/Oral Cancer Dataset/train'

# List files in the directory
files = os.listdir(path)
print(f"Files in directory: {files}")
# Out:
# Files in directory: ['class1', 'class2']

# %%
import os
from PIL import Image

def is_image(file_path):
    try:
        Image.open(file_path)
        return True
    except:
        return False

path = 'C:/Users/GEETHANJALICHARVI/OneDrive/Desktop/oral cancer copy/Oral Cancer/Oral Cancer Dataset/train'

# List files and filter out non-images
image_files = [f for f in os.listdir(path) if is_image(os.path.join(path, f))]
print(f"Valid image files: {image_files}")
# Out:
# Valid image files: []

# %%
import os

file_path = 'C:\\Users\\GEETHANJALICHARVI\\OneDrive\\Desktop\\oral cancer copy\\Oral Cancer\\Oral Cancer Dataset\\train\\class1\\CANCER'  # Replace with your actual file path
if os.path.exists(file_path):
    print(f"File exists: {file_path}")
else:
    print(f"File not found: {file_path}")
# Out:
# File exists: C:\Users\GEETHANJALICHARVI\OneDrive\Desktop\oral cancer copy\Oral Cancer\Oral Cancer Dataset\train\class1\CANCER

# %%
from tensorflow.keras.layers import Dense,Conv2D,MaxPool2D
from tensorflow.keras.models import Sequential

# %%
model = Sequential()

# %%
from tensorflow.keras.preprocessing import image_dataset_from_directory

train_dataset = image_dataset_from_directory(
    'C:\\Users\\GEETHANJALICHARVI\\OneDrive\\Desktop\\oral cancer copy\\Oral Cancer\\Oral Cancer Dataset\\train',  # Update this with your actual directory path
    image_size=(128, 128), 
    batch_size=32,
    label_mode='categorical'  # or 'binary' based on the problem
)
# Out:
# Found 950 files belonging to 2 classes.

# %%
import tensorflow as tf
from tensorflow.keras.preprocessing import image_dataset_from_directory

# %%
from tensorflow.keras.utils import load_img, img_to_array

# Load a single image for testing
img = load_img("C:\\Users\\GEETHANJALICHARVI\\OneDrive\\Desktop\\oral cancer copy\\Oral Cancer\\Oral Cancer Dataset\\train\\class1\\CANCER\\001.jpeg", target_size=(128, 128))
img_array = img_to_array(img)
print("Image shape:", img_array.shape)  # Expected: (128, 128, 3)
# Out:
# Image shape: (128, 128, 3)

# %%
model = Sequential()

# %%
from tensorflow.keras.layers import Conv2D, MaxPool2D, Flatten, Dense

# Your model code
model.add(Conv2D(filters=32, kernel_size=3, padding='same', activation='relu', input_shape=(128, 128,3)))
model.add(Conv2D(filters=32, kernel_size=3, activation='relu'))
model.add(MaxPool2D(pool_size=2, strides=2))

# %%
from tensorflow.keras.layers import Conv2D, MaxPool2D, Flatten, Dense

# Your model code
model.add(Conv2D(filters=64, kernel_size=3, padding='same', activation='relu', input_shape=(128, 128, 3)))
model.add(Conv2D(filters=64, kernel_size=3, padding='same', activation='relu'))
model.add(MaxPool2D(pool_size=2, strides=2))

# %%
from tensorflow.keras.layers import Conv2D, MaxPool2D, Flatten, Dense

# Your model code
model.add(Conv2D(filters=128, kernel_size=3, padding='same', activation='relu', input_shape=(128, 128, 3)))
model.add(Conv2D(filters=128, kernel_size=3, padding='same', activation='relu'))
model.add(MaxPool2D(pool_size=2, strides=2))

# %%
from tensorflow.keras.layers import Conv2D, MaxPool2D, Flatten, Dense

# Your model code
model.add(Conv2D(filters=256, kernel_size=3, padding='same', activation='relu', input_shape=(128, 128, 3)))
model.add(Conv2D(filters=256, kernel_size=3, padding='same', activation='relu'))
model.add(MaxPool2D(pool_size=2, strides=2))

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPool2D, Flatten, Dense, Dropout
model = Sequential()



model.add(Dropout(0.25)) # to aviod over fitting

# %%
model.add(Flatten())

# %%
model.add(Dense(units=1024, activation='relu'))

# %%
model.add(Dropout(0.4))

# %%
#output layer 
model.add(Dense(units=38,activation='softmax'))

# %%
model.compile(optimizer=tf.keras.optimizers.Adam(
    learning_rate=0.0001), loss='categorical_crossentropy', metrics=['accuracy'])

# %%
model.summary()

# %%
model.add(Dense(1, activation='sigmoid'))  # 1 output for binary classification

# %%
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

# %%
model.add(Dense(38, activation='softmax'))  # 38 outputs for 38 classes

# %%
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# %%
model = tf.keras.Sequential([
    Conv2D(filters=32, kernel_size=3, padding='same', activation='relu', input_shape=(128, 128, 3)),
    Conv2D(filters=32, kernel_size=3, padding='same', activation='relu'),
    MaxPool2D(pool_size=2, strides=2),
    Flatten(),
    Dense(128, activation='relu'),
    Dense(38, activation='softmax')  # 38 output neurons for 38 classes
])

model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# %%
training_history =  model.fit(x=training_set,validation_data=validation_set,epochs=10)
# Out:
# Epoch 1/10
# -----------------------------------------------------------------
# InvalidArgumentError            Traceback (most recent call last)
# Cell In[28], line 1
# ----> 1 training_history =  model.fit(x=training_set,validation_data=validation_set,epochs=10)
#
# File c:\Users\GEETHANJALICHARVI\anaconda3\envs\tensorflow_env\lib\site-packages\keras\utils\traceback_utils.py:70, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      67     filtered_tb = _process_traceback_frames(e.__traceback__)
#      68     # To get the full stack trace, call:
#      69     # `tf.debugging.disable_traceback_filtering()`
# ---> 70     raise e.with_traceback(filtered_tb) from None
#      71 finally:
#      72     del filtered_tb
#
# File c:\Users\GEETHANJALICHARVI\anaconda3\envs\tensorflow_env\lib\site-packages\tensorflow\python\eager\execute.py:54, in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      52 try:
#      53   ctx.ensure_initialized()
# ...
